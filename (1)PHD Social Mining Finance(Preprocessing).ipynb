# %% [markdown]
# What is Alpha?

# %% [markdown]
# Alpha

# %% [markdown]
# 1. Alpha factors are designed to extract signals from data to predict asset returns for a given investment universe over the trading horizon. A factor takes on a single value for each asset when evaluated, but may combine one or several input variables.
#
# 2. Alpha factors emit entry and exit signals that lead to buy or sell orders, and order execution results in portfolio holdings. The risk profiles of individual positions interact to create a specific portfolio risk profile. Portfolio management involves the optimization of position weights to achieve the desired portfolio risk and return a profile that aligns with the overall investment objectives. This process is highly dynamic to incorporate continuously-evolving market data.

# %% [markdown]
# Signals derived from alpha factors are often individually weak, but sufficiently powerful when combined with other factors or data sources, for example, to modulate the signal as a function of the market or economic context.

# %% [markdown]
# # Preprocessing Train Stock Factors and Tweets

# %% [markdown]
# ## Importing Data and Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
smf=pd.read_csv('train_factors.csv')
json=pd.read_json('train_data.json')

# %%
# x = []
# y = []
# z = []
# a = []
# for i in json.records:
#     x.append(i['stocktwit_tweet'])
#     y.append(i['sentiment_score'])
#     z.append(pd.to_datetime(i['timestamp']))
#     a.append(i['ticker'])

# json_data = pd.DataFrame({'Tweet':x, 
#                          'Sentiment_score':y,
#                          'Date':z,
#                          'Stock':a})

# %%
# json_data.to_csv('json_df_train.csv',index=False)
json_df=pd.read_csv('json_df_train.csv')

# %%
smf.sort_values(by='date').head()
# Out:
#           Id      date ticker       SF1       SF2       SF3       SF4  \
# 13579  13580  01/07/18   $CHK  0.923545 -0.243410 -0.158433 -0.287238
# 12721  12722  01/07/18    $EA -0.633291 -0.490767 -0.100732  0.406717
# 5253    5254  01/07/18   $MPC  0.990107 -2.222850 -0.296034 -1.159469
# 18031  18032  01/07/18   $RRD -0.072173  1.129222 -0.595059 -0.920225
# 13028  13029  01/07/18  $WYNN  0.774560  0.942843 -0.500773 -1.594142
#
#             SF5       SF6       SF7  alpha
# 13579 -0.289620 -0.778008  1.019364      3
# 12721  0.618815 -1.398402 -0.767455      2
# 5253  -0.117747 -0.411154  1.636414      1
# 18031  1.145811  0.670895  0.649400      2
# 13028  0.388954 -0.264942  1.764325      3

# %% [markdown]
# ## Data Exploring and Cleaning

# %%
smf['date']=pd.to_datetime(smf['date'].astype(str),format="%d/%m/%y")

# %%
smf.sort_values(by='date').head()
# Out:
#           Id       date ticker       SF1       SF2       SF3       SF4  \
# 25420  25421 2018-07-01  $FBHS -0.127743 -0.662712  0.524711 -0.356265
# 19929  19930 2018-07-01   $CBS  0.520310  0.612894 -0.047482 -0.062071
# 10725  10726 2018-07-01   $NKE  0.854953 -0.598153  0.356626 -0.360109
# 25200  25201 2018-07-01  $HOLX -0.235685 -0.284623  0.051159  0.700647
# 12721  12722 2018-07-01    $EA -0.633291 -0.490767 -0.100732  0.406717
#
#             SF5       SF6       SF7  alpha
# 25420 -0.962408 -0.349525 -0.041011      1
# 19929 -0.238253 -1.047546  0.503267      2
# 10725 -1.252869 -0.376943  0.863024      4
# 25200  0.091861  0.992291 -0.638230      2
# 12721  0.618815 -1.398402 -0.767455      2

# %%
json_df['Date_T']=json_df['Date'].str.split(expand=True)[0]
json_df['Time']=json_df['Date'].str.split(expand=True)[1]
json_df['Date_T']=pd.to_datetime(json_df['Date_T'])
json_df.drop(['Date','Time'],inplace=True,axis=1)

# %%
json_df.sort_values(by='Date_T').head()
# Out:
#                                                     Tweet  Sentiment_score  \
# 72094                                       $CLF 9 Monday                4
# 588364  $AAPL absolutely true. And throwing more bodie...                2
# 109383  insider ownership of #Davita is 2.16% $DVA #DV...                2
# 109430  $SBUX the chart look so ugly without a clear s...                1
# 894168  $AMD this board needs to be more active on wee...                2
#
#         Stock     Date_T
# 72094    $CLF 2018-07-01
# 588364  $AAPL 2018-07-01
# 109383   $DVA 2018-07-01
# 109430  $SBUX 2018-07-01
# 894168   $AMD 2018-07-01

# %% [markdown]
# ### Removing Duplicated Rows

# %%
json_df.duplicated(keep=False).sum()
# Out:
# 43312

# %%
json_df.duplicated().sum()
# Out:
# 29173

# %%
json_df.drop_duplicates(keep='first',inplace=True)

# %%
json_df=json_df.reset_index(drop=True)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score  Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   $AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   $CAT
# 2                                         $AVGO WTF?                2  $AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    $PH
# 4  $FB if it bounces tommorrow do the right thing...                3    $FB
#
#       Date_T
# 0 2018-09-19
# 1 2018-10-09
# 2 2018-07-12
# 3 2018-07-19
# 4 2018-08-23

# %% [markdown]
# ### Cleaning Stock Ticker SMF

# %%
smf['ticker']=smf['ticker'].str.replace('$','')
smf['ticker']=smf['ticker'].str.upper()

# %% [markdown]
# ### Cleaning Stock Ticker JSON

# %%
json_df['Stock']=json_df['Stock'].str.replace('$','')
json_df['Stock']=json_df['Stock'].str.upper()

# %%
smf.head()
# Out:
#    Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0   1 2018-08-21   NTAP -0.628652  0.988891 -0.055714  0.774379  0.551089
# 1   2 2018-10-11   WYNN  1.315786  1.438754  0.187327  0.608933 -1.153030
# 2   3 2018-08-21    DRI -1.141388 -1.455016  0.332755  0.674502  0.111326
# 3   4 2018-07-10     GE -0.054839 -1.454149 -0.162267 -0.681870  0.307869
# 4   5 2018-09-12     FE -0.686366  0.838865  0.073830  0.679024  0.329463
#
#         SF6       SF7  alpha
# 0 -1.329229 -0.995539      2
# 1  1.859441  0.730995      3
# 2 -0.478597 -1.488157      1
# 3 -0.529987  0.404172      2
# 4  1.262782 -1.024042      2

# %%
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T
# 0 2018-09-19
# 1 2018-10-09
# 2 2018-07-12
# 3 2018-07-19
# 4 2018-08-23

# %% [markdown]
# ## Feature Engineering TP

# %% [markdown]
# ### Feature Engineering  For SMF

# %% [markdown]
# #### Adding Month

# %%
smf['Month']=smf['date'].dt.month

# %% [markdown]
# #### Adding Day

# %%
smf['Day']=smf['date'].dt.day

# %% [markdown]
# #### Adding WeekDay

# %%
smf['WeekDay']=smf['date'].dt.weekday

# %% [markdown]
# #### Adding WeekNumber

# %%
weeknumber=[]
for i in range(smf.shape[0]):
    weeknumber.append(smf['date'][i].isocalendar()[1])
smf['WeekNumber']=weeknumber

# %% [markdown]
# ### Feature Engineering For JSON

# %% [markdown]
# #### Adding Month

# %%
json_df['Month']=json_df['Date_T'].dt.month

# %% [markdown]
# #### Adding Day

# %%
json_df['Day']=json_df['Date_T'].dt.day

# %% [markdown]
# #### Adding WeekDay

# %%
json_df['WeekDay']=json_df['Date_T'].dt.weekday

# %% [markdown]
# #### Adding WeekNumber

# %%
weeknumber=[]
for i in range(json_df.shape[0]):
    weeknumber.append(json_df['Date_T'][i].isocalendar()[1])
json_df['WeekNumber']=weeknumber

# %%
smf.head()
# Out:
#    Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0   1 2018-08-21   NTAP -0.628652  0.988891 -0.055714  0.774379  0.551089
# 1   2 2018-10-11   WYNN  1.315786  1.438754  0.187327  0.608933 -1.153030
# 2   3 2018-08-21    DRI -1.141388 -1.455016  0.332755  0.674502  0.111326
# 3   4 2018-07-10     GE -0.054839 -1.454149 -0.162267 -0.681870  0.307869
# 4   5 2018-09-12     FE -0.686366  0.838865  0.073830  0.679024  0.329463
#
#         SF6       SF7  alpha  Month  Day  WeekDay  WeekNumber
# 0 -1.329229 -0.995539      2      8   21        1          34
# 1  1.859441  0.730995      3     10   11        3          41
# 2 -0.478597 -1.488157      1      8   21        1          34
# 3 -0.529987  0.404172      2      7   10        1          28
# 4  1.262782 -1.024042      2      9   12        2          37

# %%
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34

# %% [markdown]
# ## Saving Cleaned SMF Data to CSV

# %%
smf.to_csv('smf_cleaned_train_val.csv',index=False)

# %% [markdown]
# ## Cleaning JSON(Textual Data)

# %%
import spacy
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
import unicodedata

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
nlp = spacy.load('en', parse = False, tag=False, entity=False)
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %% [markdown]
# ## Removing and Parsing Html Tags

# %%
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_html.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tweet'].apply(strip_html_tags)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet
# 0  $AMD going up but hesitating however chart is ...
# 1  @inforlong @MariaGascon Despite\nChina trade w...
# 2                                         $AVGO WTF?
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...
# 4  $FB if it bounces tommorrow do the right thing...

# %% [markdown]
# ## Feature Engineering(Continued)

# %% [markdown]
# ### Feature Engineering adding Punctuation Percentage

# %%
import string
def count_punct(text):
    count = sum([1 for char in text if char in string.punctuation])
    return round(count/(len(text) - text.count(" ")), 3)*100

# %%
json_df['Punctuation_%'] = json_df['Tidy_Tweet'].apply(lambda x: count_punct(x))

# %% [markdown]
# ### Feature Engineering adding Text Length

# %%
json_df['Text Length'] = json_df['Tidy_Tweet'].apply(lambda x: len(x) - x.count(" "))

# %%
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0  $AMD going up but hesitating however chart is ...            1.6
# 1  @inforlong @MariaGascon Despite\nChina trade w...            5.0
# 2                                         $AVGO WTF?           22.2
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...           11.0
# 4  $FB if it bounces tommorrow do the right thing...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ## Cleaning Json Tweet (Continued)

# %% [markdown]
# ### Removing Http and www from Tweet

# %%
# json_df['Tidy_Tweet'] = np.vectorize(remove_pattern)(json_df['Tidy_Tweet'], "http[\w]*") 
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttp.csv',index=False)
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace('http\S*|www.\S*','', case=False)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0  $AMD going up but hesitating however chart is ...            1.6
# 1  @inforlong @MariaGascon Despite\nChina trade w...            5.0
# 2                                         $AVGO WTF?           22.2
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...           11.0
# 4  $FB if it bounces tommorrow do the right thing...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing Repeating Words in Tweet

# %%
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].apply(lambda x : re.sub(r'(.)\1{1,}', r'\1\1', x) )

# %% [markdown]
# ### Converting Emojis to Words

# %%
import emoji

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(lambda x: emoji.demojize(x))

# %%
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace(":", "",regex=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace("_", " ",regex=False)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0  $AMD going up but hesitating however chart is ...            1.6
# 1  @inforlong @MariaGascon Despite\nChina trade w...            5.0
# 2                                         $AVGO WTF?           22.2
# 3  $PH\n New Insider Filing On \n MULLER KLAUS PE...           11.0
# 4  $FB if it bounces tommorrow do the right thing...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing @ Twitter Handles from Tweet

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@.csv',index=False)
json_df['Tidy_Tweet'] =json_df['Tidy_Tweet'].str.replace("@[\w]*","")
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0  $AMD going up but hesitating however chart is ...            1.6
# 1    Despite\nChina trade war $CAT held very well...            5.0
# 2                                         $AVGO WTF?           22.2
# 3  $PH\n New Insider Filing On \n MULLER KLAUS PE...           11.0
# 4  $FB if it bounces tommorrow do the right thing...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing dollarsign from Tweet

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace("\$[\w]*","")
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0   going up but hesitating however chart is very...            1.6
# 1    Despite\nChina trade war  held very well thu...            5.0
# 2                                               WTF?           22.2
# 3  \n New Insider Filing On \n MULLER KLAUS PETER...           11.0
# 4   if it bounces tommorrow do the right thing an...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing Accented Chars from Tweet

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accented.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(remove_accented_chars)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0   going up but hesitating however chart is very...            1.6
# 1    Despite\nChina trade war  held very well thu...            5.0
# 2                                               WTF?           22.2
# 3  \n New Insider Filing On \n MULLER KLAUS PETER...           11.0
# 4   if it bounces tommorrow do the right thing an...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Lower Text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlower.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.lower()
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0   going up but hesitating however chart is very...            1.6
# 1    despite\nchina trade war  held very well thu...            5.0
# 2                                               wtf?           22.2
# 3  \n new insider filing on \n muller klaus peter...           11.0
# 4   if it bounces tommorrow do the right thing an...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Expanding Contractions

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %%
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(expand_contractions)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0   going up but hesitating however chart is very...            1.6
# 1    despite\nchina trade war  held very well thu...            5.0
# 2                                               wtf?           22.2
# 3  \n new insider filing on \n muller klaus peter...           11.0
# 4   if it bounces tommorrow do the right thing an...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing Punctuations, Numbers,Special Characters and Unnecessary Hashtags

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecial.csv',index=False)
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace("[#+]?\B", "")
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0   going up but hesitating however chart is very...            1.6
# 1    despite china trade war  held very well thum...            5.0
# 2                                               wtf            22.2
# 3    new insider filing on   muller klaus peter t...           11.0
# 4   if it bounces tommorrow do the right thing an...            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Removing Stopwords

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecialstp.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(remove_stopwords)
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0  going hesitating however chart stable going up...            1.6
# 1           despite china trade war held well thumbs            5.0
# 2                                                wtf           22.2
# 3  new insider filing muller klaus peter transact...           11.0
# 4                 bounces tommorrow right thing gtfo            2.2
#
#    Text Length
# 0           62
# 1           60
# 2            9
# 3          100
# 4           45

# %% [markdown]
# ### Stemming Text

# %%
# from nltk import WordNetLemmatizer
# lemmatizer = WordNetLemmatizer()
# tokenized_tweet = tokenized_tweet.apply(lambda x: [lemmatizer.lemmatize(i) for i in x])
# json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecialstplemma.csv',index=False)
# json_df.iloc[121411:121414]
tokenized_tweet = json_df['Tidy_Tweet'].apply(lambda x: x.split()) 
tokenized_tweet.head()
# Out:
# 0    [going, hesitating, however, chart, stable, go...
# 1     [despite, china, trade, war, held, well, thumbs]
# 2                                                [wtf]
# 3    [new, insider, filing, muller, klaus, peter, t...
# 4             [bounces, tommorrow, right, thing, gtfo]
# Name: Tidy_Tweet, dtype: object

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])
tokenized_tweet.head()
# Out:
# 0         [go, hesit, howev, chart, stabl, go, upward]
# 1       [despit, china, trade, war, held, well, thumb]
# 2                                                [wtf]
# 3    [new, insid, file, muller, klau, peter, transa...
# 4               [bounc, tommorrow, right, thing, gtfo]
# Name: Tidy_Tweet, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
json_df['Tidy_Tweet'] = tokenized_tweet
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                        Tidy_Tweet  Punctuation_%  Text Length
# 0            go hesit howev chart stabl go upward            1.6           62
# 1          despit china trade war held well thumb            5.0           60
# 2                                             wtf           22.2            9
# 3  new insid file muller klau peter transact code           11.0          100
# 4                bounc tommorrow right thing gtfo            2.2           45

# %% [markdown]
# ### Check Null Rows and Removing Blank Tweets

# %%
temp_checkpoint = json_df
temp_checkpoint.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                        Tidy_Tweet  Punctuation_%  Text Length
# 0            go hesit howev chart stabl go upward            1.6           62
# 1          despit china trade war held well thumb            5.0           60
# 2                                             wtf           22.2            9
# 3  new insid file muller klau peter transact code           11.0          100
# 4                bounc tommorrow right thing gtfo            2.2           45

# %%
test_tidy=temp_checkpoint[temp_checkpoint['Tidy_Tweet']!=""]
test_tidy.isnull().sum()
# Out:
# Tweet              0
# Sentiment_score    0
# Stock              0
# Date_T             0
# Month              0
# Day                0
# WeekDay            0
# WeekNumber         0
# Tidy_Tweet         0
# Punctuation_%      0
# Text Length        0
# dtype: int64

# %%
test_tidy[test_tidy['Tidy_Tweet']==""]
# Out:
# Empty DataFrame
# Columns: [Tweet, Sentiment_score, Stock, Date_T, Month, Day, WeekDay, WeekNumber, Tidy_Tweet, Punctuation_%, Text Length]
# Index: []

# %%
test_tidy.isnull().sum()
# Out:
# Tweet              0
# Sentiment_score    0
# Stock              0
# Date_T             0
# Month              0
# Day                0
# WeekDay            0
# WeekNumber         0
# Tidy_Tweet         0
# Punctuation_%      0
# Text Length        0
# dtype: int64

# %%
json_df=test_tidy

# %%
json_df.head()
# Out:
#                                                Tweet  Sentiment_score Stock  \
# 0  $AMD going up but hesitating however chart is ...                3   AMD
# 1  @inforlong @MariaGascon Despite\nChina trade w...                3   CAT
# 2                                         $AVGO WTF?                2  AVGO
# 3  $PH\n New Insider Filing On: \n MULLER KLAUS P...                2    PH
# 4  $FB if it bounces tommorrow do the right thing...                3    FB
#
#       Date_T  Month  Day  WeekDay  WeekNumber  \
# 0 2018-09-19      9   19        2          38
# 1 2018-10-09     10    9        1          41
# 2 2018-07-12      7   12        3          28
# 3 2018-07-19      7   19        3          29
# 4 2018-08-23      8   23        3          34
#
#                                        Tidy_Tweet  Punctuation_%  Text Length
# 0            go hesit howev chart stabl go upward            1.6           62
# 1          despit china trade war held well thumb            5.0           60
# 2                                             wtf           22.2            9
# 3  new insid file muller klau peter transact code           11.0          100
# 4                bounc tommorrow right thing gtfo            2.2           45

# %%
json_df.shape
# Out:
# (986803, 11)

# %% [markdown]
# ## Saving Cleaned JSON(Textual Data)

# %%
json_df.drop('Tweet',axis=1,inplace=True)

# %%
json_df.to_csv('json_df_cleaned_train_val.csv',index=False)

# %% [markdown]
# ## Fin

# %% [markdown]
# # Preprocessing Test Stock Factors and Tweets

# %% [markdown]
# ## Import Data and Libraries

# %%
smf=pd.read_csv('test_factors.csv')
json=pd.read_json('test_data.json')

# %%
# x = []
# ##y = []
# z = []
# a = []
# for i in json.records:
#     x.append(i['stocktwit_tweet'])
#     #y.append(i['sentiment_score'])
#     z.append(pd.to_datetime(i['timestamp']))
#     a.append(i['ticker'])

# json_data = pd.DataFrame({'Tweet':x, 
#                          #'Sentiment_score':y,
#                          'Date':z,
#                          'Stock':a})

# %%
# json_data.to_csv('json_df_test.csv',index=False)
json_df=pd.read_csv('json_df_test.csv')

# %%
smf.sort_values(by='date').head()
# Out:
#            Id      date ticker       SF1       SF2       SF3       SF4  \
# 4513   274520  01/07/18  $NVDA -1.248715  0.600227 -0.051088  2.189014
# 7000   277007  01/07/18   $KSS  1.297563 -1.492159  0.378980  0.644587
# 11372  281379  01/07/18  $AMAT  0.131374 -2.249649  0.104021  0.610359
# 9805   279812  01/07/18  $GOOG  0.831799  0.279735  0.419933  0.053564
# 10055  280062  01/07/18   $TSN  0.022721 -1.116382  0.100513  0.343247
#
#             SF5       SF6       SF7
# 4513   1.019032  0.294410 -2.382914
# 7000  -1.512155 -0.245498  0.641642
# 11372 -0.247068 -2.268079 -0.278888
# 9805  -1.335868 -2.135489  0.578237
# 10055 -0.188535 -0.999391 -0.212836

# %% [markdown]
# ## Data Exploring and Cleaning

# %%
smf['date']=pd.to_datetime(smf['date'].astype(str),format="%d/%m/%y")

# %%
smf.sort_values(by='date').head()
# Out:
#           Id       date ticker       SF1       SF2       SF3       SF4  \
# 9048  279055 2018-07-01  $SNPS  0.802727  0.259343 -0.587202  0.542434
# 7427  277434 2018-07-01   $WHR -0.142381  1.655428 -0.005262 -0.695668
# 5216  275223 2018-07-01  $CBRE -0.838393 -0.662745  1.318567 -2.103852
# 2463  272470 2018-07-01   $CNC -1.816650 -1.974370  0.184403  0.319560
# 1982  271989 2018-07-01   $URI -0.512415  0.356740  0.636302 -0.866115
#
#            SF5       SF6       SF7
# 9048  0.671571  0.104758  0.534639
# 7427  0.056611  0.233851  0.293441
# 5216 -2.168325  0.338990  0.169036
# 2463  0.801997 -0.217545 -1.823715
# 1982 -0.969422 -0.768523 -0.101548

# %%
json_df['Date_T']=json_df['Date'].str.split(expand=True)[0]
json_df['Time']=json_df['Date'].str.split(expand=True)[1]
json_df['Date_T']=pd.to_datetime(json_df['Date_T'])
json_df.drop(['Date','Time'],inplace=True,axis=1)

# %%
json_df.sort_values(by='Date_T').head()
# Out:
#                                                     Tweet Stock     Date_T
# 177101  $T own 427 shares and buying more on payday th...    $T 2018-07-01
# 74702   $CHK the 15 min chart from Friday indicating s...  $CHK 2018-07-01
# 61216   $AMD the chase continues, hopefully they catch...  $AMD 2018-07-01
# 13010   Short sale volume (not short interest) for $WP...  $WPX 2018-07-01
# 191134  Recent $ICE technical alerts: Bollinger Band S...  $ICE 2018-07-01

# %% [markdown]
# ### Remove Duplicated Rows

# %%
json_df.duplicated(keep=False).sum()
# Out:
# 6245

# %%
json_df.duplicated().sum()
# Out:
# 3880

# %%
json_df.drop_duplicates(keep='first',inplace=True)

# %%
json_df=json_df.reset_index(drop=True)
json_df.head()
# Out:
#                                                Tweet  Stock     Date_T
# 0                   $CELG nothing to be exited about  $CELG 2018-10-25
# 1  $AMD yall exhaust your buyer on first green ca...   $AMD 2018-07-13
# 2                              $AMD day traders day.   $AMD 2018-09-25
# 3                    $CBS https://tenor.com/wLB8.gif   $CBS 2018-07-27
# 4  $MU weak price action so far today. Don’t be a...    $MU 2018-07-31

# %% [markdown]
# ### Cleaning Stock Ticker SMF

# %%
smf['ticker']=smf['ticker'].str.replace('$','')
smf['ticker']=smf['ticker'].str.upper()

# %% [markdown]
# ### Cleaning Stock Ticker JSON

# %%
json_df['Stock']=json_df['Stock'].str.replace('$','')
json_df['Stock']=json_df['Stock'].str.upper()

# %%
smf.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007 2018-07-21   INTC -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008 2018-10-05   CTSH  0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009 2018-10-01     CB  0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010 2018-10-24   CTAS -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011 2018-07-27   INTC  0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7
# 0 -0.274912 -4.504449
# 1  0.046276  0.826353
# 2 -0.601060  1.012811
# 3 -0.553581 -0.683803
# 4  0.126153  0.297111

# %%
json_df.head()
# Out:
#                                                Tweet Stock     Date_T
# 0                   $CELG nothing to be exited about  CELG 2018-10-25
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13
# 2                              $AMD day traders day.   AMD 2018-09-25
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31

# %% [markdown]
# ## Feature Engineering TP

# %% [markdown]
# ### Feature Engineering  For SMF

# %% [markdown]
# #### Adding Month

# %%
smf['Month']=smf['date'].dt.month

# %% [markdown]
# #### Adding Day

# %%
smf['Day']=smf['date'].dt.day

# %% [markdown]
# #### Adding WeekDay

# %%
smf['WeekDay']=smf['date'].dt.weekday

# %% [markdown]
# #### Adding WeekNumber

# %%
weeknumber=[]
for i in range(smf.shape[0]):
    weeknumber.append(smf['date'][i].isocalendar()[1])
smf['WeekNumber']=weeknumber

# %% [markdown]
# ### Feature Engineering For JSON

# %% [markdown]
# #### Adding Month

# %%
json_df['Month']=json_df['Date_T'].dt.month

# %% [markdown]
# #### Adding Day

# %%
json_df['Day']=json_df['Date_T'].dt.day

# %% [markdown]
# #### Adding WeekDay

# %%
json_df['WeekDay']=json_df['Date_T'].dt.weekday

# %% [markdown]
# #### Adding WeekNumber

# %%
weeknumber=[]
for i in range(json_df.shape[0]):
    weeknumber.append(json_df['Date_T'][i].isocalendar()[1])
json_df['WeekNumber']=weeknumber

# %%
smf.head()
# Out:
#        Id       date ticker       SF1       SF2       SF3       SF4       SF5  \
# 0  270007 2018-07-21   INTC -3.062194  1.223466  1.741714  2.279266 -1.323573
# 1  270008 2018-10-05   CTSH  0.816263 -2.184408  0.157975 -0.264743 -0.836282
# 2  270009 2018-10-01     CB  0.401281  0.091604  0.083411 -1.147041 -0.485223
# 3  270010 2018-10-24   CTAS -0.783521  1.192929  0.813831 -0.368166 -1.113656
# 4  270011 2018-07-27   INTC  0.796507  0.455341  0.679032  0.354336 -1.799055
#
#         SF6       SF7  Month  Day  WeekDay  WeekNumber
# 0 -0.274912 -4.504449      7   21        5          29
# 1  0.046276  0.826353     10    5        4          40
# 2 -0.601060  1.012811     10    1        0          40
# 3 -0.553581 -0.683803     10   24        2          43
# 4  0.126153  0.297111      7   27        4          30

# %%
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31

# %% [markdown]
# ## Saving Cleaned SMF Data to CSV

# %%
smf.to_csv('smf_cleaned_test.csv',index=False)

# %% [markdown]
# ## Cleaning JSON(Textual Data)

# %%
import spacy
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
import unicodedata

# %%
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
nlp = spacy.load('en', parse = False, tag=False, entity=False)
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %% [markdown]
# ## Removing and Parsing Html Tags

# %%
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_html.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tweet'].apply(strip_html_tags)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber                                         Tidy_Tweet
# 0   25        3          43                   $CELG nothing to be exited about
# 1   13        4          28  $AMD yall exhaust your buyer on first green ca...
# 2   25        1          39                              $AMD day traders day.
# 3   27        4          30                    $CBS https://tenor.com/wLB8.gif
# 4   31        1          31  $MU weak price action so far today. Don’t be a...

# %% [markdown]
# ## Feature Engineering(Continued)

# %% [markdown]
# ### Feature Engineering adding Punctuation Percentage

# %%
import string
def count_punct(text):
    count = sum([1 for char in text if char in string.punctuation])
    return round(count/(len(text) - text.count(" ")), 3)*100

# %%
json_df['Punctuation_%'] = json_df['Tidy_Tweet'].apply(lambda x: count_punct(x))

# %% [markdown]
# ### Feature Engineering adding Text Length

# %%
json_df['Text Length'] = json_df['Tidy_Tweet'].apply(lambda x: len(x) - x.count(" "))

# %%
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                   $CELG nothing to be exited about            3.7
# 1  $AMD yall exhaust your buyer on first green ca...            9.3
# 2                              $AMD day traders day.           11.1
# 3                    $CBS https://tenor.com/wLB8.gif           23.3
# 4  $MU weak price action so far today. Don’t be a...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ## Cleaning Json Tweet (Continued)

# %% [markdown]
# ### Removing Http and www from Tweet

# %%
# json_df['Tidy_Tweet'] = np.vectorize(remove_pattern)(json_df['Tidy_Tweet'], "http[\w]*") 
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttp.csv',index=False)
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace('http\S*|www.\S*','', case=False)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                   $CELG nothing to be exited about            3.7
# 1  $AMD yall exhaust your buyer on first green ca...            9.3
# 2                              $AMD day traders day.           11.1
# 3                                              $CBS            23.3
# 4  $MU weak price action so far today. Don’t be a...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing Repeating Words in Tweet

# %%
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].apply(lambda x : re.sub(r'(.)\1{1,}', r'\1\1', x) )

# %% [markdown]
# ### Converting Emojis to Words

# %%
import emoji

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(lambda x: emoji.demojize(x))

# %%
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace(":", "",regex=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace("_", " ",regex=False)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                   $CELG nothing to be exited about            3.7
# 1  $AMD yall exhaust your buyer on first green ca...            9.3
# 2                              $AMD day traders day.           11.1
# 3                                              $CBS            23.3
# 4  $MU weak price action so far today. Don’t be a...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing @ Twitter Handles from Tweet

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@.csv',index=False)
json_df['Tidy_Tweet'] =json_df['Tidy_Tweet'].str.replace("@[\w]*","")
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                   $CELG nothing to be exited about            3.7
# 1  $AMD yall exhaust your buyer on first green ca...            9.3
# 2                              $AMD day traders day.           11.1
# 3                                              $CBS            23.3
# 4  $MU weak price action so far today. Don’t be a...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing dollarsign from Tweet

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.replace("\$[\w]*","")
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                         nothing to be exited about            3.7
# 1   yall exhaust your buyer on first green candle...            9.3
# 2                                   day traders day.           11.1
# 3                                                              23.3
# 4   weak price action so far today. Don’t be afra...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing Accented Chars from Tweet

# %%
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accented.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(remove_accented_chars)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                         nothing to be exited about            3.7
# 1   yall exhaust your buyer on first green candle...            9.3
# 2                                   day traders day.           11.1
# 3                                                              23.3
# 4   weak price action so far today. Dont be afrai...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Lower Text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlower.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].str.lower()
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                         nothing to be exited about            3.7
# 1   yall exhaust your buyer on first green candle...            9.3
# 2                                   day traders day.           11.1
# 3                                                              23.3
# 4   weak price action so far today. dont be afrai...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Expanding Contractions

# %%
def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
                                if contraction_mapping.get(match)\
                                else contraction_mapping.get(match.lower())                       
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
        
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %%
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(expand_contractions)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                         nothing to be exited about            3.7
# 1   yall exhaust your buyer on first green candle...            9.3
# 2                                   day traders day.           11.1
# 3                                                              23.3
# 4   weak price action so far today. dont be afrai...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing Punctuations, Numbers,Special Characters and Unnecessary Hashtags

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecial.csv',index=False)
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
json_df['Tidy_Tweet'] = json_df['Tidy_Tweet'].str.replace("[#+]?\B", "")
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                         nothing to be exited about            3.7
# 1   yall exhaust your buyer on first green candle...            9.3
# 2                                   day traders day            11.1
# 3                                                              23.3
# 4   weak price action so far today  dont be afrai...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Removing Stopwords

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
#json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecialstp.csv',index=False)
json_df['Tidy_Tweet']=json_df['Tidy_Tweet'].apply(remove_stopwords)
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                                     nothing exited            3.7
# 1         yall exhaust buyer first green candle byee            9.3
# 2                                    day traders day           11.1
# 3                                                              23.3
# 4  weak price action far today dont afraid go sho...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Stemming Text

# %%
# from nltk import WordNetLemmatizer
# lemmatizer = WordNetLemmatizer()
# tokenized_tweet = tokenized_tweet.apply(lambda x: [lemmatizer.lemmatize(i) for i in x])
# json_df['Tidy_Tweet'].to_csv('tidy_tweet_htmlhttpemo@$accentedlowercontractspecialstplemma.csv',index=False)
# json_df.iloc[121411:121414]
tokenized_tweet = json_df['Tidy_Tweet'].apply(lambda x: x.split()) 
tokenized_tweet.head()
# Out:
# 0                                    [nothing, exited]
# 1    [yall, exhaust, buyer, first, green, candle, b...
# 2                                  [day, traders, day]
# 3                                                   []
# 4    [weak, price, action, far, today, dont, afraid...
# Name: Tidy_Tweet, dtype: object

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x])
tokenized_tweet.head()
# Out:
# 0                                         [noth, exit]
# 1    [yall, exhaust, buyer, first, green, candl, byee]
# 2                                   [day, trader, day]
# 3                                                   []
# 4    [weak, price, action, far, today, dont, afraid...
# Name: Tidy_Tweet, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])
json_df['Tidy_Tweet'] = tokenized_tweet
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                                          noth exit            3.7
# 1          yall exhaust buyer first green candl byee            9.3
# 2                                     day trader day           11.1
# 3                                                              23.3
# 4  weak price action far today dont afraid go sho...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %% [markdown]
# ### Check Null Rows and Removing Blank Tweets

# %%
temp_checkpoint = json_df
temp_checkpoint.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 3                    $CBS https://tenor.com/wLB8.gif   CBS 2018-07-27      7
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 3   27        4          30
# 4   31        1          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                                          noth exit            3.7
# 1          yall exhaust buyer first green candl byee            9.3
# 2                                     day trader day           11.1
# 3                                                              23.3
# 4  weak price action far today dont afraid go sho...            3.4
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 3           30
# 4           88

# %%
test_tidy=temp_checkpoint[temp_checkpoint['Tidy_Tweet']!=""]
test_tidy.isnull().sum()
# Out:
# Tweet            0
# Stock            0
# Date_T           0
# Month            0
# Day              0
# WeekDay          0
# WeekNumber       0
# Tidy_Tweet       0
# Punctuation_%    0
# Text Length      0
# dtype: int64

# %%
test_tidy[test_tidy['Tidy_Tweet']==""]
# Out:
# Empty DataFrame
# Columns: [Tweet, Stock, Date_T, Month, Day, WeekDay, WeekNumber, Tidy_Tweet, Punctuation_%, Text Length]
# Index: []

# %%
test_tidy.isnull().sum()
# Out:
# Tweet            0
# Stock            0
# Date_T           0
# Month            0
# Day              0
# WeekDay          0
# WeekNumber       0
# Tidy_Tweet       0
# Punctuation_%    0
# Text Length      0
# dtype: int64

# %%
json_df=test_tidy

# %%
json_df.head()
# Out:
#                                                Tweet Stock     Date_T  Month  \
# 0                   $CELG nothing to be exited about  CELG 2018-10-25     10
# 1  $AMD yall exhaust your buyer on first green ca...   AMD 2018-07-13      7
# 2                              $AMD day traders day.   AMD 2018-09-25      9
# 4  $MU weak price action so far today. Don’t be a...    MU 2018-07-31      7
# 5  $AMZN continues to grow, specifically in key a...  AMZN 2018-08-04      8
#
#    Day  WeekDay  WeekNumber  \
# 0   25        3          43
# 1   13        4          28
# 2   25        1          39
# 4   31        1          31
# 5    4        5          31
#
#                                           Tidy_Tweet  Punctuation_%  \
# 0                                          noth exit            3.7
# 1          yall exhaust buyer first green candl byee            9.3
# 2                                     day trader day           11.1
# 4  weak price action far today dont afraid go sho...            3.4
# 5  continu grow specif key area like cloud comput...            3.7
#
#    Text Length
# 0           27
# 1           54
# 2           18
# 4           88
# 5          108

# %%
json_df.shape
# Out:
# (254741, 10)

# %% [markdown]
# ## Saving Cleaned JSON(Textual Data)

# %%
json_df.drop('Tweet',axis=1,inplace=True)

# %%
json_df.to_csv('json_df_cleaned_test.csv',index=False)

# %% [markdown]
# ## Fin
